# %% [markdown]
# | Nombre Original               |  Traducción               |
# |-------------------------------|----------------------------------|
# | ACCOUNT_PROMOTER              | PROMOTOR_CUENTA                  |
# | ARRANGEMENT_DATE              | FECHA_ACUERDO                    |
# | ASSOCIATED_PURCHASE           | COMPRA_ASOCIADA                  |
# | BRANCH_OFFICE                 | SUCURSAL                         |
# | CANCELATION                   | CANCELACIÓN                      |
# | CAPTURED_AFTER_HOUR           | CAPTURADO_FUERA_HORARIO          |
# | CLEAN_INTEREST                | INTERÉS_LIMPIO                   |
# | COMMISIONS_AMOUNT             | MONTO_COMISIONES                 |
# | COMMISIONS_VAT_AMOUNT         | MONTO_IVA_COMISIONES             |
# | COMPLEMENTARY_INFO_ID         | ID_INFO_COMPLEMENTARIA           |
# | CONAFOR_ORI_RES               | RES_ORI_CONAFOR                  |
# | CONAFOR_PROVINCE              | PROVINCIA_CONAFOR                |
# | CONAFOR_SUPPORT               | APOYO_CONAFOR                    |
# | CONAFOR_SUPPORT_2             | APOYO_CONAFOR_2                  |
# | COUNTERPARTY_ACCOUNT          | CUENTA_CONTRAPARTE               |
# | CPARTY_CUST_ACC               | CUENTA_CLIENTE_CONTRAPARTE       |
# | CUST_BALANCE_AGREEMENT        | ACUERDO_BALANCE_CLIENTE          |
# | DISCRIM_TYPE                  | TIPO_DISCRIM                     |
# | DOLLARS_AMOUNT                | MONTO_DÓLARES                    |
# | DOLLARS_EX_RATE               | TIPO_CAMBIO_DÓLARES              |
# | ENTRY_DATE                    | FECHA_ENTRADA                    |
# | ENTRY_MODE                    | MODO_ENTRADA                     |
# | ENTRY_USER_ID                 | ID_USUARIO_ENTRADA               |
# | EXTERNAL_ID                   | ID_EXTERNO                       |
# | FINANCIAL_PROCESS             | PROCESO_FINANCIERO               |
# | FOLIO_INCONFID                | FOLIO_INCONFID                   |
# | FUT_CLEAN_INTEREST            | INTERÉS_LIMPIO_FUT               |
# | FUT_TOT                       | FUT_TOT                          |
# | GENERATED_SURPLUS             | EXCEDENTE_GENERADO               |
# | GROSS_AMOUNT                  | MONTO_BRUTO                      |
# | INCOME_TAX_AMOUNT             | MONTO_IMPUESTO_RENTA             |
# | INVEST_ACCOUNT                | CUENTA_INVERSIÓN                 |
# | INVESTOR_MANAGER              | GESTOR_INVERSOR                  |
# | IS_CTT_MODE_FOREIGN           | ES_MODO_CTT_EXTRANJERO           |
# | IS_CTT_TYPE_PURCHASE          | ES_TIPO_CTT_COMPRA               |
# | IS_EXTERNALLY_MODIFIED        | ES_MODIFICADO_EXTERNAMENTE       |
# | IS_FULL_SALE                  | ES_VENTA_COMPLETA                |
# | IS_RECLASSIFICATION           | ES_RECLASIFICACIÓN               |
# | IS_REIMBURSEMENT              | ES_REEMBOLSO                     |
# | IS_TES                        | ES_TES                           |
# | MECA_NUMBER                   | NÚMERO_MECA                      |
# | MT103_OPTIONAL_VALUES         | VALORES_OPCIONALES_MT103         |
# | NEGOTIATION_MODE              | MODO_NEGOCIACIÓN                 |
# | OID                           | OID                              |
# | OP_BY_FINES                   | OP_POR_MULTAS                    |
# | OP_BY_TECH_COMITTEE           | OP_POR_COMITÉ_TÉCNICO            |
# | ORDERED_AMOUNT                | MONTO_ORDENADO                   |
# | ORIGIN_TX_CBA                 | ORIGEN_TX_CBA                    |
# | ORIGIN_TX_ENTRY_NUMBER        | NÚMERO_ENTRADA_ORIGEN_TX         |
# | ORIGIN_TX_ID                  | ID_ORIGEN_TX                     |
# | OVERSION                      | OVERSION                         |
# | PARENT_TRANSACTION            | TRANSACCIÓN_PADRE                |
# | PARTY_ACCOUNT                 | CUENTA_PARTE                     |
# | PARTY_CUST_ACC                | CUENTA_CLIENTE_PARTE             |
# | PAYMENT_DISPERSION_FNAME      | NOMBRE_ARCHIVO_DISPERSIÓN_PAGO   |
# | PCA_COUNTPARTY_CURRENCY       | MONEDA_CONTRAPARTE_PCA           |
# | PCA_COUNTPARTY_SERIES         | SERIE_CONTRAPARTE_PCA            |
# | PCA_PARTY_CURRENCY            | MONEDA_PARTE_PCA                 |
# | PCA_PARTY_SERIES              | SERIE_PARTE_PCA                  |
# | PF_MOVS_FILE_NAME             | NOMBRE_ARCHIVO_MOVS_PF           |
# | PRI_SERIES_AGREEDATE          | FECHA_ACUERDO_SERIE_PRI          |
# | PRI_SERIES_AGREETERM          | PLAZO_ACUERDO_SERIE_PRI          |
# | PRI_SERIES_AMOUNT             | MONTO_SERIE_PRI                  |
# | PRI_SERIES_FUT_AGREEDATE      | FECHA_ACUERDO_FUT_SERIE_PRI      |
# | PRI_SERIES_FUT_PRICE          | PRECIO_FUT_SERIE_PRI             |
# | PRI_SERIES_FUT_RATE           | TASA_FUT_SERIE_PRI               |
# | PRI_SERIES_FUT_TERM           | PLAZO_FUT_SERIE_PRI              |
# | PRI_SERIES_PRICE              | PRECIO_SERIE_PRI                 |
# | PRI_SERIES_RATE               | TASA_SERIE_PRI                   |
# | PRI_SERIES_STOCKAMOUNT        | MONTO_ACCIONES_SERIE_PRI         |
# | PRICE_DATE                    | FECHA_PRECIO                     |
# | PRIMARY_SERIES                | SERIE_PRIMARIA                   |
# | REF                           | REFERENCIA                       |
# | REF_RATE_AMOUNT               | MONTO_TASA_REF                   |
# | REF_RATE_OVERAMOUNT           | MONTO_SOBRETASA_REF              |
# | REF_RATE_SERIES               | SERIE_TASA_REF                   |
# | REJECTION                     | RECHAZO                          |
# | RETURN_SURPLUS                | DEVOLUCIÓN_EXCEDENTE             |
# | SEC_SERIES_AGREEDATE          | FECHA_ACUERDO_SERIE_SEC          |
# | SEC_SERIES_AGREETERM          | PLAZO_ACUERDO_SERIE_SEC          |
# | SEC_SERIES_AMORT              | AMORT_SERIE_SEC                  |
# | SEC_SERIES_AMOUNT             | MONTO_SERIE_SEC                  |
# | SEC_SERIES_EXRATE             | TIPO_CAMBIO_SERIE_SEC            |
# | SEC_SERIES_FUT_AGREEDATE      | FECHA_ACUERDO_FUT_SERIE_SEC      |
# | SEC_SERIES_FUT_TERM           | PLAZO_FUT_SERIE_SEC              |
# | SEC_SERIES_INCOME             | INGRESO_SERIE_SEC                |
# | SECONDARY_SERIES              | SERIE_SECUNDARIA                 |
# | SETTL_EVENT_NUMBER            | NÚMERO_EVENTO_LIQUIDACIÓN        |
# | SETTL_MODE                    | MODO_LIQUIDACIÓN                 |
# | SETTLE_IN_DOLLARS             | LIQUIDAR_EN_DÓLARES              |
# | SETTLEMENT_DATE               | FECHA_LIQUIDACIÓN                |
# | SPTN                          | SPTN                             |
# | STOCK_TYPE                    | TIPO_ACCIONES                    |
# | STOCKAMOUNT                   | MONTO_ACCIONES                   |
# | SUB_ACCOUNT                   | SUBCUENTA                        |
# | TER_SERIES_AMOUNT             | MONTO_SERIE_TER                  |
# | TERTIARY_SERIES               | SERIE_TERCIARIA                  |
# | TF_MONTH_AND_YEAR             | MES_Y_AÑO_TF                     |
# | TF_PAYMENT                    | PAGO_TF                          |
# | TF_PAYMENT_DEP_DATE           | FECHA_DEPÓSITO_PAGO_TF           |
# | TF_PAYMENT_DEPOSIT            | DEPÓSITO_PAGO_TF                 |
# | TOT                           | TOT                              |
# | TRANSACTION_DAYS              | DÍAS_TRANSACCIÓN                 |
# | TRANSACTION_END_DATE          | FECHA_FIN_TRANSACCIÓN            |
# | TRANSACTION_INTEREST          | INTERÉS_TRANSACCIÓN              |
# | TRANSACTION_RATE              | TASA_TRANSACCIÓN                 |
# | TRUST_GOAL                    | OBJETIVO_FIDEICOMISO             |
# | TX_ACCEPT_NUMBER              | NÚMERO_ACEPTACIÓN_TX             |
# | TX_COMMENTS                   | COMENTARIOS_TX                   |
# | TX_CONCEPT                    | CONCEPTO_TX                      |
# | TX_ENTRY_NUMBER               | NÚMERO_ENTRADA_TX                |
# | TX_HISTORY                    | HISTORIAL_TX                     |
# | TX_PREV_STATE                 | ESTADO_ANTERIOR_TX               |
# | TX_STATE                      | ESTADO_TX                        |
# | TX_SUBTYPE                    | SUBTIPO_TX                       |
# | TX_TYPE                       | TIPO_TX                          |
# | USED_SURPLUS                  | EXCEDENTE_UTILIZADO              |
# | VAT_AMOUNT                    | MONTO_IVA                        |

# %%
mapeo = {
    "ACCOUNT_PROMOTER": "PROMOTOR_CUENTA",
    "ARRANGEMENT_DATE": "FECHA_ACUERDO",
    "ASSOCIATED_PURCHASE": "COMPRA_ASOCIADA",
    "BRANCH_OFFICE": "SUCURSAL",
    "CANCELATION": "CANCELACIÓN",
    "CAPTURED_AFTER_HOUR": "CAPTURADO_FUERA_HORARIO",
    "CLEAN_INTEREST": "INTERÉS_LIMPIO",
    "COMMISIONS_AMOUNT": "MONTO_COMISIONES",
    "COMMISIONS_VAT_AMOUNT": "MONTO_IVA_COMISIONES",
    "COMPLEMENTARY_INFO_ID": "ID_INFO_COMPLEMENTARIA",
    "CONAFOR_ORI_RES": "RES_ORI_CONAFOR",
    "CONAFOR_PROVINCE": "PROVINCIA_CONAFOR",
    "CONAFOR_SUPPORT": "APOYO_CONAFOR",
    "CONAFOR_SUPPORT_2": "APOYO_CONAFOR_2",
    "COUNTERPARTY_ACCOUNT": "CUENTA_CONTRAPARTE",
    "CPARTY_CUST_ACC": "CUENTA_CLIENTE_CONTRAPARTE",
    "CUST_BALANCE_AGREEMENT": "ACUERDO_BALANCE_CLIENTE",
    "DISCRIM_TYPE": "TIPO_DISCRIM",
    "DOLLARS_AMOUNT": "MONTO_DÓLARES",
    "DOLLARS_EX_RATE": "TIPO_CAMBIO_DÓLARES",
    "ENTRY_DATE": "FECHA_ENTRADA",
    "ENTRY_MODE": "MODO_ENTRADA",
    "ENTRY_USER_ID": "ID_USUARIO_ENTRADA",
    "EXTERNAL_ID": "ID_EXTERNO",
    "FINANCIAL_PROCESS": "PROCESO_FINANCIERO",
    "FOLIO_INCONFID": "FOLIO_INCONFID",
    "FUT_CLEAN_INTEREST": "INTERÉS_LIMPIO_FUT",
    "FUT_TOT": "FUT_TOT",
    "GENERATED_SURPLUS": "EXCEDENTE_GENERADO",
    "GROSS_AMOUNT": "MONTO_BRUTO",
    "INCOME_TAX_AMOUNT": "MONTO_IMPUESTO_RENTA",
    "INVEST_ACCOUNT": "CUENTA_INVERSIÓN",
    "INVESTOR_MANAGER": "GESTOR_INVERSOR",
    "IS_CTT_MODE_FOREIGN": "ES_MODO_CTT_EXTRANJERO",
    "IS_CTT_TYPE_PURCHASE": "ES_TIPO_CTT_COMPRA",
    "IS_EXTERNALLY_MODIFIED": "ES_MODIFICADO_EXTERNAMENTE",
    "IS_FULL_SALE": "ES_VENTA_COMPLETA",
    "IS_RECLASSIFICATION": "ES_RECLASIFICACIÓN",
    "IS_REIMBURSEMENT": "ES_REEMBOLSO",
    "IS_TES": "ES_TES",
    "MECA_NUMBER": "NÚMERO_MECA",
    "MT103_OPTIONAL_VALUES": "VALORES_OPCIONALES_MT103",
    "NEGOTIATION_MODE": "MODO_NEGOCIACIÓN",
    "OID": "OID",
    "OP_BY_FINES": "OP_POR_MULTAS",
    "OP_BY_TECH_COMITTEE": "OP_POR_COMITÉ_TÉCNICO",
    "ORDERED_AMOUNT": "MONTO_ORDENADO",
    "ORIGIN_TX_CBA": "ORIGEN_TX_CBA",
    "ORIGIN_TX_ENTRY_NUMBER": "NÚMERO_ENTRADA_ORIGEN_TX",
    "ORIGIN_TX_ID": "ID_ORIGEN_TX",
    "OVERSION": "OVERSION",
    "PARENT_TRANSACTION": "TRANSACCIÓN_PADRE",
    "PARTY_ACCOUNT": "CUENTA_PARTE",
    "PARTY_CUST_ACC": "CUENTA_CLIENTE_PARTE",
    "PAYMENT_DISPERSION_FNAME": "NOMBRE_ARCHIVO_DISPERSIÓN_PAGO",
    "PCA_COUNTPARTY_CURRENCY": "MONEDA_CONTRAPARTE_PCA",
    "PCA_COUNTPARTY_SERIES": "SERIE_CONTRAPARTE_PCA",
    "PCA_PARTY_CURRENCY": "MONEDA_PARTE_PCA",
    "PCA_PARTY_SERIES": "SERIE_PARTE_PCA",
    "PF_MOVS_FILE_NAME": "NOMBRE_ARCHIVO_MOVS_PF",
    "PRI_SERIES_AGREEDATE": "FECHA_ACUERDO_SERIE_PRI",
    "PRI_SERIES_AGREETERM": "PLAZO_ACUERDO_SERIE_PRI",
    "PRI_SERIES_AMOUNT": "MONTO_SERIE_PRI",
    "PRI_SERIES_FUT_AGREEDATE": "FECHA_ACUERDO_FUT_SERIE_PRI",
    "PRI_SERIES_FUT_PRICE": "PRECIO_FUT_SERIE_PRI",
    "PRI_SERIES_FUT_RATE": "TASA_FUT_SERIE_PRI",
    "PRI_SERIES_FUT_TERM": "PLAZO_FUT_SERIE_PRI",
    "PRI_SERIES_PRICE": "PRECIO_SERIE_PRI",
    "PRI_SERIES_RATE": "TASA_SERIE_PRI",
    "PRI_SERIES_STOCKAMOUNT": "MONTO_ACCIONES_SERIE_PRI",
    "PRICE_DATE": "FECHA_PRECIO",
    "PRIMARY_SERIES": "SERIE_PRIMARIA",
    "REF": "REFERENCIA",
    "REF_RATE_AMOUNT": "MONTO_TASA_REF",
    "REF_RATE_OVERAMOUNT": "MONTO_SOBRETASA_REF",
    "REF_RATE_SERIES": "SERIE_TASA_REF",
    "REJECTION": "RECHAZO",
    "RETURN_SURPLUS": "DEVOLUCIÓN_EXCEDENTE",
    "SEC_SERIES_AGREEDATE": "FECHA_ACUERDO_SERIE_SEC",
    "SEC_SERIES_AGREETERM": "PLAZO_ACUERDO_SERIE_SEC",
    "SEC_SERIES_AMORT": "AMORT_SERIE_SEC",
    "SEC_SERIES_AMOUNT": "MONTO_SERIE_SEC",
    "SEC_SERIES_EXRATE": "TIPO_CAMBIO_SERIE_SEC",
    "SEC_SERIES_FUT_AGREEDATE": "FECHA_ACUERDO_FUT_SERIE_SEC",
    "SEC_SERIES_FUT_TERM": "PLAZO_FUT_SERIE_SEC",
    "SEC_SERIES_INCOME": "INGRESO_SERIE_SEC",
    "SECONDARY_SERIES": "SERIE_SECUNDARIA",
    "SETTL_EVENT_NUMBER": "NÚMERO_EVENTO_LIQUIDACIÓN",
    "SETTL_MODE": "MODO_LIQUIDACIÓN",
    "SETTLE_IN_DOLLARS": "LIQUIDAR_EN_DÓLARES",
    "SETTLEMENT_DATE": "FECHA_LIQUIDACIÓN",
    "SPTN": "SPTN",
    "STOCK_TYPE": "TIPO_ACCIONES",
    "STOCKAMOUNT": "MONTO_ACCIONES",
    "SUB_ACCOUNT": "SUBCUENTA",
    "TER_SERIES_AMOUNT": "MONTO_SERIE_TER",
    "TERTIARY_SERIES": "SERIE_TERCIARIA",
    "TF_MONTH_AND_YEAR": "MES_Y_AÑO_TF",
    "TF_PAYMENT": "PAGO_TF",
    "TF_PAYMENT_DEP_DATE": "FECHA_DEPÓSITO_PAGO_TF",
    "TF_PAYMENT_DEPOSIT": "DEPÓSITO_PAGO_TF",
    "TOT": "TOT",
    "TRANSACTION_DAYS": "DÍAS_TRANSACCIÓN",
    "TRANSACTION_END_DATE": "FECHA_FIN_TRANSACCIÓN",
    "TRANSACTION_INTEREST": "INTERÉS_TRANSACCIÓN",
    "TRANSACTION_RATE": "TASA_TRANSACCIÓN",
    "TRUST_GOAL": "OBJETIVO_FIDEICOMISO",
    "TX_ACCEPT_NUMBER": "NÚMERO_ACEPTACIÓN_TX",
    "TX_COMMENTS": "COMENTARIOS_TX",
    "TX_CONCEPT": "CONCEPTO_TX",
    "TX_ENTRY_NUMBER": "NÚMERO_ENTRADA_TX",
    "TX_HISTORY": "HISTORIAL_TX",
    "TX_PREV_STATE": "ESTADO_ANTERIOR_TX",
    "TX_STATE": "ESTADO_TX",
    "TX_SUBTYPE": "SUBTIPO_TX",
    "TX_TYPE": "TIPO_TX",
    "USED_SURPLUS": "EXCEDENTE_UTILIZADO",
    "VAT_AMOUNT": "MONTO_IVA"
}

# %%
from utils.tf import *
from utils.db import *
from utils.gd import * 
from utils.clt_repetidos import *
from datetime import datetime
import cx_Oracle
import pandas as pd
import os
import plotly.express as px
import plotly.graph_objects as go
from utils.clt_repetidos import *

# %%
import configparser

config = configparser.ConfigParser()

config.read('/home/ale1726/proyects/datalake/input/datalake.ini')
db_sifc = {'NAME':config['sifc']['name'],'USER':config['sifc']['user'],'PSSWD':config['sifc']['psswd'],'DSN':config['sifc']['dsn'],'SCHEMA':config['sifc']['schema']}

# %%
query = """
WITH CLIENTES_ACTIVOS AS (
	SELECT OID OID_CUSTOMERS, CUSTOMER_ID, LEGAL_NAME, DESCRIPTION, RFC, ADDRESS_DUMP 
	FROM SIFC.CUSTOMERS 
	WHERE CUSTOMER_STATUS = 'ACTIVE' 
), CLIENTES_ACCOUNTS AS (
	SELECT CA.*, AC.OID OID_ACCOUNTS, AC.RFC RFC2
	FROM CLIENTES_ACTIVOS CA
	LEFT JOIN SIFC.ACCOUNTS AC ON CA.OID_CUSTOMERS = AC.CUSTOMER
), CLIENTES_TRANS AS (
	SELECT CAC.*, "OID" ID_TRANSACTION, ENTRY_DATE FECHA_DE_ENTRADA, TA.ARRANGEMENT_DATE FECHA_DE_ACUERDO, 
	TA.SETTLEMENT_DATE FECHA_DE_LIQUIDACION, PRI_SERIES_AGREEDATE FECHA_DE_ACUERDO_SERIE_PRI, 
	SEC_SERIES_AGREEDATE FECHA_DE_ACUERDO_SERIE_SEC, TRANSACTION_END_DATE FECHA_DE_FIN_DE_TRANSACCION, 
	TRANSACTION_RATE TASA_DE_TRANSACCION, TX_COMMENTS COMENTARIOS_TX, TX_CONCEPT CONCEPTO_TX, 
	TRUST_GOAL OBJETIVO_DEL_FIDEICOMISO, TX_SUBTYPE SUBTIPO_TX, COMMISIONS_AMOUNT MONTO_DE_COMISIONES, 
	FUT_CLEAN_INTEREST INTERES_LIMPIO_FUTURO, USED_SURPLUS EXCEDENTE_UTILIZADO, DOLLARS_AMOUNT MONTO_EN_DOLARES, 
	DOLLARS_EX_RATE TASA_DE_CAMBIO_DOLARES, PRI_SERIES_AMOUNT MONTO_SERIE_PRI, GROSS_AMOUNT MONTO_BRUTO, 
	ORDERED_AMOUNT MONTO_ORDENADO
	FROM CLIENTES_ACCOUNTS CAC
	LEFT JOIN SIFC.TRANSACTIONS TA ON TA.PARTY_ACCOUNT = CAC.OID_ACCOUNTS
), CLIENTES_DISP AS (
	SELECT CTR.*, PAYD."OID" ID_DISPERSION, PAYD.AMOUNT MONTO_DISPERSION, PAYD.BENEFICIARY_NAME NOMBRE_DE_BENEFICIARIO, PAYD.RFC RFC_BENEFICIARIO
	FROM CLIENTES_TRANS CTR
	LEFT JOIN SIFC.PAYMENT_DISPERSIONS PAYD ON PAYD."TRANSACTION" = CTR.ID_TRANSACTION
) SELECT * FROM CLIENTES_DISP WHERE ID_TRANSACTION IS NOT NULL
"""

# %%
get_table("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/04062025", db_sifc, "productos_sifc", query=query)
# Out:
# '/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/04062025/productos_sifc.dat'

# %%
df  = pd.read_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/04062025/productos_sifc.dat", low_memory=False)

# %%
df[df["LEGAL_NAME"].str.contains("AAA")]
# Out:
#          OID_CUSTOMERS  CUSTOMER_ID                     LEGAL_NAME  \
# 19056             3785        80284                      AAA HOMEX
# 19057             3818        80420                    AAA SORIANA
# 19058             3845        80587  FIDEICOMISO AAA CONSORCIO ARA
# 19059             3832        80510             AAA GRUPO ROTOPLAS
# 19064             3837        80542             AAA KIMBERLY CLARK
# ...                ...          ...                            ...
# 3215319           3785        80284                      AAA HOMEX
# 3215502           3822        80456                      AAA BIMBO
# 3215511           3784        80281        AAA ELEKTRA DEL MILENIO
# 3215514           3822        80456                      AAA BIMBO
# 3215596           3784        80281        AAA ELEKTRA DEL MILENIO
#
#                            DESCRIPTION            RFC  \
# 19056                        AAA HOMEX  XXXXXXXXXXXXX
# ...

# %%
del df

# %%
df
# Out:
#          OID_CUSTOMERS  CUSTOMER_ID  \
# 0                 3091        80139
# 1                 3091        80139
# 2                 3091        80139
# 3                 3091        80139
# 4                 3091        80139
# ...                ...          ...
# 3149400           4423        80320
# 3149401           4423        80320
# 3149402           4423        80320
# 3149403           4478        80615
# 3149404           4423        80320
#
#                                                 LEGAL_NAME  \
# 0        Fideicomiso de Contragarantia para el Financia...
# 1        Fideicomiso de Contragarantia para el Financia...
# 2        Fideicomiso de Contragarantia para el Financia...
# 3        Fideicomiso de Contragarantia para el Financia...
# 4        Fideicomiso de Contragarantia para el Financia...
# ...                                                    ...
# 3149400            FONDO DE PENSIONES DEL SISTEMA BANRURAL
# ...

# %% [markdown]
# # Catalogos

# %%
df.columns
# Out:
# Index(['OID_CUSTOMERS', 'CUSTOMER_ID', 'LEGAL_NAME', 'DESCRIPTION', 'RFC',
#        'ADDRESS_DUMP', 'OID_ACCOUNTS', 'RFC2', 'ID_TRANSACTION',
#        'FECHA_DE_ENTRADA', 'FECHA_DE_ACUERDO', 'FECHA_DE_LIQUIDACION',
#        'FECHA_DE_ACUERDO_SERIE_PRI', 'FECHA_DE_ACUERDO_SERIE_SEC',
#        'FECHA_DE_FIN_DE_TRANSACCION', 'TASA_DE_TRANSACCION', 'COMENTARIOS_TX',
#        'CONCEPTO_TX', 'OBJETIVO_DEL_FIDEICOMISO', 'SUBTIPO_TX',
#        'MONTO_DE_COMISIONES', 'INTERES_LIMPIO_FUTURO', 'EXCEDENTE_UTILIZADO',
#        'MONTO_EN_DOLARES', 'TASA_DE_CAMBIO_DOLARES', 'MONTO_SERIE_PRI',
#        'MONTO_BRUTO', 'MONTO_ORDENADO', 'ID_DISPERSION', 'MONTO_DISPERSION',
#        'NOMBRE_DE_BENEFICIARIO', 'RFC_BENEFICIARIO'],
#       dtype='object')

# %%
tx_concept = pd.read_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/TX_CONCEPTS.csv", low_memory=False)

# %%
TRANSACTION_SUBTYPES =  pd.read_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/TRANSACTION_SUBTYPES.csv")

# %%
TRUST_GOAL  = pd.read_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/TRUST_GOAL.csv")

# %%
df["CONCEPTO_TX"] = df["CONCEPTO_TX"].apply(lambda x: tx_concept.loc[tx_concept["OID"] == x, "DESCRIPTION"].values[0] if pd.notna(x) and not tx_concept.loc[tx_concept["OID"] == x, "DESCRIPTION"].empty else x)

# %%
df["SUBTIPO_TX"] = df["SUBTIPO_TX"].apply(lambda x: TRANSACTION_SUBTYPES.loc[TRANSACTION_SUBTYPES["OID"] == x, "DESCRIPTION"].values[0] if pd.notna(x) and not TRANSACTION_SUBTYPES.loc[TRANSACTION_SUBTYPES["OID"] == x, "DESCRIPTION"].empty else x)

# %%
df["TRUST_GOAL"] = df["TRUST_GOAL"].apply(lambda x: TRUST_GOAL.loc[TRUST_GOAL["OID"] == x, "DESCRIPTION"].values[0] if pd.notna(x) and not TRUST_GOAL.loc[TRUST_GOAL["OID"] == x, "DESCRIPTION"].empty else x)

# %%
df.to_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/prod_2_sifc.dat", index=False)

# %%
df[df["TRUST_GOAL"].notnull()].head(5)
# Out:
#       OID_CUSTOMERS  CUSTOMER_ID                              LEGAL_NAME  \
# 1210           3089        11480  Fondo para la Participacion de Riesgos
# 1211           3089        11480  Fondo para la Participacion de Riesgos
# 1212           3089        11480  Fondo para la Participacion de Riesgos
# 1213           3089        11480  Fondo para la Participacion de Riesgos
# 1215           3089        11480  Fondo para la Participacion de Riesgos
#
#                                  DESCRIPTION            RFC  \
# 1210  Fondo para la Participacion de Riesgos  XXXXXXXXXXXXX
# 1211  Fondo para la Participacion de Riesgos  XXXXXXXXXXXXX
# 1212  Fondo para la Participacion de Riesgos  XXXXXXXXXXXXX
# 1213  Fondo para la Participacion de Riesgos  XXXXXXXXXXXXX
# 1215  Fondo para la Participacion de Riesgos  XXXXXXXXXXXXX
#
#                                            ADDRESS_DUMP  OID_ACCOUNTS  \
# 1210  1020|||DISTRITO FEDERAL|ALVARO OBREGON |GUADAL...         34141
# ...

# %%
df= pd.read_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/prod_2_sifc.dat", low_memory=False)

# %%
df

# %%
report = ProfileReport(df, title='Informe EDA productos')
report.to_file("my_report_sifc.html")

# %%
df

# %% [markdown]
# ## Limpieza

# %%
df= pd.read_csv("/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/prod_2_sifc.dat", low_memory=False)

# %%
from ydata_profiling import ProfileReport

# %%
report = ProfileReport(df, title='Informe EDA productos')
report.to_file("my_report_sifc.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df

# %%
df.rename(columns={column: mapeo[column] if column in mapeo else column for column in df.columns}, inplace=True)

# %%
df.columns
# Out:
# Index(['OID_CUSTOMERS', 'CUSTOMER_ID', 'LEGAL_NAME', 'DESCRIPTION', 'RFC',
#        'ADDRESS_DUMP', 'OID_ACCOUNTS', 'RFC2', 'ID_TRANSACTION',
#        'FECHA_DE_ENTRADA', 'FECHA_DE_ACUERDO', 'FECHA_DE_LIQUIDACION',
#        'FECHA_DE_ACUERDO_SERIE_PRI', 'FECHA_DE_ACUERDO_SERIE_SEC',
#        'FECHA_DE_FIN_DE_TRANSACCION', 'TASA_DE_TRANSACCION', 'COMENTARIOS_TX',
#        'CONCEPTO_TX', 'OBJETIVO_DEL_FIDEICOMISO', 'SUBTIPO_TX',
#        'MONTO_DE_COMISIONES', 'INTERES_LIMPIO_FUTURO', 'EXCEDENTE_UTILIZADO',
#        'MONTO_EN_DOLARES', 'TASA_DE_CAMBIO_DOLARES', 'MONTO_SERIE_PRI',
#        'MONTO_BRUTO', 'MONTO_ORDENADO', 'ID_DISPERSION', 'MONTO_DISPERSION',
#        'NOMBRE_DE_BENEFICIARIO', 'RFC_BENEFICIARIO'],
#       dtype='object')

# %%
df["FECHA_DE_ENTRADA"] =  pd.to_datetime(df['FECHA_DE_ENTRADA'])
df["FECHA_DE_ACUERDO"] =  pd.to_datetime(df['FECHA_DE_ACUERDO'])
df["FECHA_DE_LIQUIDACION"] =  pd.to_datetime(df['FECHA_DE_LIQUIDACION'])
df["FECHA_DE_ACUERDO_SERIE_PRI"] =  pd.to_datetime(df['FECHA_DE_ACUERDO_SERIE_PRI'])
df["FECHA_DE_ACUERDO_SERIE_SEC"] =  pd.to_datetime(df['FECHA_DE_ACUERDO_SERIE_SEC'])
df["FECHA_DE_FIN_DE_TRANSACCION"] =  pd.to_datetime(df['FECHA_DE_FIN_DE_TRANSACCION'])

# %%
df["AÑO_ENTRADA"] = df["FECHA_DE_ENTRADA"].apply(lambda x: x.year) 
df["MES_ENTRADA"] = df["FECHA_DE_ENTRADA"].apply(lambda x: x.month)
df["AÑO_ACUERDO"] = df["FECHA_DE_ACUERDO"].apply(lambda x: x.year)
df["MES_ACUERDO"] = df["FECHA_DE_ACUERDO"].apply(lambda x: x.month)
df["AÑO_LIQUIDACIÓN"] = df["FECHA_DE_LIQUIDACION"].apply(lambda x: x.year)
df["MES_LIQUIDACIÓN"] = df["FECHA_DE_LIQUIDACION"].apply(lambda x: x.month)

# %%
df["FEC"]

# %%
df.value_counts("SUBTIPO_TX")
# Out:
# SUBTIPO_TX
# CORTO PLAZO                                    803541
# Conciliación SIFC - TAS                        162199
# Pago de honorarios con cargo al patrimonio       8051
# Pago de honorarios con depósito del cliente      4819
# LARGO PLAZO                                      2172
# Inicialización de Acuerdos                         17
# Name: count, dtype: int64

# %%
df.value_counts("CONCEPTO_TX")
# Out:
# CONCEPTO_TX
# ENTREGA PATRIMONIAL                     457215
# PAGO DE ACREEDORES DIVERSOS             152663
# APOYO  A PYMES                           41546
# RETIROS DE PATRIMONIO                    37774
# PAGO DE GARANTIAS SIN COMISION E IVA     33282
#                                          ...
# ENTERO DE IVA                                1
# FONDEO PARA PAGO DE RETENCIONES              1
# PRESTAMO DEUDORES DIVERSOS                   1
# PAGO DE ISR RETENIDO                         1
# 235106                                       1
# Name: count, Length: 109, dtype: int64

# %%
df.value_counts("OBJETIVO_FIDEICOMISO")

# %%
df.describe()
# Out:
#        OID_CUSTOMERS   CUSTOMER_ID  OID_ACCOUNTS  ID_TRANSACTION  \
# count   3.149405e+06  3.149405e+06  3.149405e+06    3.149405e+06
# mean    4.256007e+03  7.718894e+04  5.861705e+04    2.256201e+06
# min     3.087000e+03  4.700000e+01  3.414100e+04    2.734840e+05
# 25%     3.091000e+03  8.013900e+04  3.760900e+04    1.326548e+06
# 50%     4.390000e+03  8.028000e+04  3.887100e+04    2.300809e+06
# 75%     4.436000e+03  8.048100e+04  7.847000e+04    3.219371e+06
# max     8.763000e+03  8.047912e+06  1.427000e+05    4.014177e+06
# std     1.257545e+03  5.592069e+04  2.893893e+04    1.084587e+06
#
#                     FECHA_DE_ENTRADA               FECHA_DE_ACUERDO  \
# count                        3149405                        3149405
# mean   2019-01-12 00:11:24.403593728  2019-01-11 21:09:28.883457024
# min              2012-02-01 09:04:24            2012-01-01 00:00:00
# 25%              2016-01-21 14:31:20            2016-01-22 00:00:00
# ...

# %%
df["ADDRESS_DUMP"] = df["ADDRESS_DUMP"].apply(lambda x: "|".join([elemento for elemento in x.split('|') if elemento != '']))

# %%
df.sample(5)
# Out:
#          OID_CUSTOMERS  CUSTOMER_ID  \
# 799724            3091        80139
# 992674            3091        80139
# 2474710           7537        80292
# 2538177           8577        80772
# 1176660           3092        80280
#
#                                                 LEGAL_NAME  \
# 799724   Fideicomiso de Contragarantia para el Financia...
# 992674   Fideicomiso de Contragarantia para el Financia...
# 2474710   FONDO DE SEGURIDAD PUBLICA DEL ESTADO DE CHIAPAS
# 2538177                    Fideicomiso de Garantía BM BBVA
# 1176660                 FIDEICOMISO DE CAPITAL EMPRENDEDOR
#
#                                                DESCRIPTION            RFC  \
# 799724   Fideicomiso de Contragarantia para el Financia...  XXXXXXXXXXXXX
# 992674   Fideicomiso de Contragarantia para el Financia...  XXXXXXXXXXXXX
# 2474710   FONDO DE SEGURIDAD PUBLICA DEL ESTADO DE CHIAPAS  XXXXXXXXXXXXX
# 2538177                    Fideicomiso de Garantía BM BBVA            NaN
# ...

# %%
df["ADDRESS_DUMP"].unique()
# Out:
# array(['1020|DISTRITO FEDERAL|MEXICO|GUADALUPE INN|AV. INSURGENTES SUR| 1971 TORRE IV PISO 5',
#        '1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 TORRE IV PISO 5',
#        '1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 TORRE IV PISO 3 ',
#        '1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 TORRE IV PISO12 PLAZA INN',
#        '1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 PISO 11 |5325-69-00',
#        '1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 TORE IV PISO 3 |53256000',
#        '1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN|INSURGENTES SUR |# 1971 EDIF. ANEXO NIVEL JARDIN',
#        '3100| |DISTRITO FEDERAL|DEL VALLE|INSURGENTES SUR| 800 PISO| ',
#        '3910| |DISTRITO FEDERAL|ALVARO OBREGON |MIXCOAC |AV. REVOLUCION |# 828| ',
#        '3910| |DISTRITO FEDERAL|BENITO JUAREZ|MIXCOAC|AV.PATRIOTISMO |# 691| ',
# ...

# %%
print(df.value_counts("ADDRESS_DUMP").to_string(max_rows=None))
# Out:
# ADDRESS_DUMP
# 1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 TORRE IV PISO12 PLAZA INN                           1084683
#                                                                                                                                   511886
# 1020|DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN |INSURGENTES SUR |# 1971 PISO 11 |5325-69-00                                   79434
# 5120| |DISTRITO FEDERAL|MEXICO DF.|BOSQUES DE LAS LOMAS|BOSQUE DE CIDROS |#  173   PISO 3|                                         74907
# 6600| |DISTRITO FEDERAL|CUAUHTEMOC|JUAREZ |HAMBURGO| 213|                                                                          56736
# 1900| |DISTRITO FEDERAL|ALVARO OBREGON|JARDINES DEL PEDREGAL|TORRE ZAFIRO, PERIFERICO SUR| 4118|                                   52818
# 1020| |DISTRITO FEDERAL|ALVARO OBREGON |GUADALUPE INN|INSURGENTES SUR |# 1971 TORRE III PISO 6 |                                   40350
# ...

# %% [markdown]
# # Agrupado dashboard

# %%
ruta_salida = "/home/ale1726/proyects/datalake/clientes/data/productos/SIFC/agrupados"

# %% [markdown]
# ### Año contra transacciones

# %%
df.columns
# Out:
# Index(['OID_CUSTOMERS', 'CUSTOMER_ID', 'LEGAL_NAME', 'DESCRIPTION', 'RFC',
#        'ADDRESS_DUMP', 'OID_ACCOUNTS', 'RFC2', 'ID_TRANSACTION',
#        'FECHA_ENTRADA', 'FECHA_ACUERDO', 'FECHA_LIQUIDACIÓN',
#        'FECHA_ACUERDO_SERIE_PRI', 'FECHA_ACUERDO_SERIE_SEC', 'MONTO_SERIE_PRI',
#        'MONTO_COMISIONES', 'FECHA_FIN_TRANSACCIÓN', 'TASA_TRANSACCIÓN',
#        'COMENTARIOS_TX', 'CONCEPTO_TX', 'OBJETIVO_FIDEICOMISO', 'SUBTIPO_TX',
#        'AÑO_ENTRADA', 'MES_ENTRADA', 'AÑO_ACUERDO', 'MES_ACUERDO',
#        'AÑO_LIQUIDACIÓN', 'MES_LIQUIDACIÓN'],
#       dtype='object')

# %%
df["CUSTOMER_ID"].nunique()
# Out:
# 292

# %%
agrupado_año_entrada  = (
    df.groupby(["AÑO_ENTRADA"], as_index=False)
    .agg(
        frecuencia = ("CUSTOMER_ID",'count'),
    )
    .sort_values('AÑO_ENTRADA', ascending=False)
)

# %%
agrupado_año_entrada["frecuencia"].max()
# Out:
# 274821

# %%
agrupado_año_entrada
# Out:
#     AÑO_ENTRADA  frecuencia
# 13         2025       33732
# 12         2024      274821
# 11         2023      262294
# 10         2022      247106
# 9          2021      238572
# 8          2020      245641
# 7          2019      270623
# 6          2018      270583
# 5          2017      261652
# 4          2016      271644
# 3          2015      249355
# 2          2014      227638
# 1          2013      197940
# 0          2012       97804

# %%
agrupado_año_mes_entrada  = (
    df.groupby(["AÑO_ENTRADA","MES_ENTRADA"], as_index=False)
    .agg(
        frecuencia = ("CUSTOMER_ID",'count'),
    )
    .sort_values(["AÑO_ENTRADA","MES_ENTRADA"], ascending=True)
)

# %%
agrupado_año_mes_entrada[agrupado_año_mes_entrada["AÑO_ENTRADA"] == 2024]["frecuencia"].to_list()
# Out:
# [23475,
#  25557,
#  17789,
#  21594,
#  21755,
#  24293,
#  25036,
#  24529,
#  24719,
#  23540,
#  20972,
#  21562]

# %%
agrupado_año_entrada.to_csv(os.path.join(ruta_salida,"agrupado_año_entrada.csv"))
agrupado_año_mes_entrada.to_csv(os.path.join(ruta_salida,"agrupado_año_mes_entrada.csv"))

# %%
agrupado_año_entrada
# Out:
#     AÑO_ENTRADA  frecuencia
# 13         2025       32412
# 12         2024      236520
# 11         2023      241867
# 10         2022      224903
# 9          2021      218765
# 8          2020      205827
# 7          2019      212409
# 6          2018      210527
# 5          2017      204484
# 4          2016      201114
# 3          2015      178692
# 2          2014      169267
# 1          2013      140367
# 0          2012       79509

# %%
agrupado_año_acuerdo  = (
    df.groupby(["AÑO_ACUERDO"], as_index=False)
    .agg(
        frecuencia = ("CUSTOMER_ID",'count'),
    )
    .sort_values('AÑO_ACUERDO', ascending=False)
)

# %%
agrupado_año_mes_acuerdo  = (
    df.groupby(["AÑO_ACUERDO", 'MES_ACUERDO'], as_index=False)
    .agg(
        frecuencia = ("CUSTOMER_ID",'count'),
    )
    .sort_values(["AÑO_ACUERDO", 'MES_ACUERDO'], ascending=True)
)

# %%
agrupado_año_acuerdo.to_csv(os.path.join(ruta_salida,"agrupado_año_acuerdo.csv"))
agrupado_año_mes_acuerdo.to_csv(os.path.join(ruta_salida,"agrupado_año_mes_acuerdo.csv"))

# %%
agrupado_año_liquidacion  = (
    df.groupby(["AÑO_LIQUIDACIÓN"], as_index=False)
    .agg(
        frecuencia = ("CUSTOMER_ID",'count'),
    )
    .sort_values('AÑO_LIQUIDACIÓN', ascending=False)
)

# %%
agrupado_año_mes_liquidacion  = (
    df.groupby(["AÑO_LIQUIDACIÓN", "MES_LIQUIDACIÓN"], as_index=False)
    .agg(
        frecuencia = ("CUSTOMER_ID",'count'),
    )
    .sort_values(["AÑO_LIQUIDACIÓN", "MES_LIQUIDACIÓN"], ascending=True)
)

# %%
agrupado_año_liquidacion.to_csv(os.path.join(ruta_salida,"agrupado_año_liquidacion.csv"))
agrupado_año_mes_liquidacion.to_csv(os.path.join(ruta_salida,"agrupado_año_mes_liquidacion.csv"))

# %% [markdown]
# # Tipo de Transacción

# %%
df.columns
# Out:
# Index(['OID_CUSTOMERS', 'CUSTOMER_ID', 'LEGAL_NAME', 'DESCRIPTION', 'RFC',
#        'ADDRESS_DUMP', 'OID_ACCOUNTS', 'RFC2', 'ID_TRANSACTION',
#        'FECHA_ENTRADA', 'FECHA_ACUERDO', 'FECHA_LIQUIDACIÓN',
#        'FECHA_ACUERDO_SERIE_PRI', 'FECHA_ACUERDO_SERIE_SEC', 'MONTO_SERIE_PRI',
#        'MONTO_COMISIONES', 'FECHA_FIN_TRANSACCIÓN', 'TASA_TRANSACCIÓN',
#        'COMENTARIOS_TX', 'CONCEPTO_TX', 'OBJETIVO_FIDEICOMISO', 'SUBTIPO_TX',
#        'AÑO_ENTRADA', 'MES_ENTRADA', 'AÑO_ACUERDO', 'MES_ACUERDO',
#        'AÑO_LIQUIDACIÓN', 'MES_LIQUIDACIÓN'],
#       dtype='object')

# %%
agrupado_producto_año = (
    df.groupby(["AÑO_ENTRADA"], as_index=False)
    .agg(
        concepto = ('CONCEPTO_TX', "nunique"),
    )
).sort_values("AÑO_ENTRADA", ascending=True)

# %%
agrupado_producto_año_mes = (
    df.groupby(["AÑO_ENTRADA","MES_ENTRADA"], as_index=False)
    .agg(
        concepto = ('CONCEPTO_TX', "nunique"),
    )
).sort_values(["AÑO_ENTRADA","MES_ENTRADA"], ascending=True)

# %%
agrupado_producto_año_mes
# Out:
#      AÑO_ENTRADA  MES_ENTRADA  concepto
# 0           2012            2        16
# 1           2012            3        12
# 2           2012            4        11
# 3           2012            5        11
# 4           2012            6        11
# ..           ...          ...       ...
# 152         2024           10        38
# 153         2024           11        35
# 154         2024           12        37
# 155         2025            1        40
# 156         2025            2        28
#
# [157 rows x 3 columns]

# %%
agrupado_producto_año.to_csv(os.path.join(ruta_salida,"agrupado_producto_año.csv"))
agrupado_producto_año_mes.to_csv(os.path.join(ruta_salida,"agrupado_producto_año_mes.csv"))

# %%
df.value_counts("COMENTARIOS_TX")

# %%
df.columns

# %%
agrupado_concepto_año = (
    df.groupby(["AÑO_ENTRADA"], as_index=False)
    .agg(
        cantidad_conceptos_x_año = ('CONCEPTO_TX', "nunique"),
    )
).sort_values("AÑO_ENTRADA", ascending=True)

# %%
agrupado_concepto_año_mes = (
    df.groupby(["AÑO_ENTRADA","MES_ENTRADA"], as_index=False)
    .agg(
        cantidad_conceptos_x_año = ('CONCEPTO_TX', "nunique"),
    )
).sort_values(["AÑO_ENTRADA","MES_ENTRADA"], ascending=True)

# %%
agrupado_concepto_año.to_csv(os.path.join(ruta_salida,"agrupado_concepto_año.csv"), index=False)
agrupado_concepto_año_mes.to_csv(os.path.join(ruta_salida,"agrupado_concepto_año_mes.csv"), index=False)

# %%
def formatear_numero(numero):
    if numero >= 1_000_000_000:
        return "{:.1f}B".format(numero / 1_000_000_000)
    elif numero >= 1_000_000:
        return "{:.1f}M".format(numero / 1_000_000)
    elif numero >= 1_000:
        return "{:.1f}K".format(numero / 1_000)
    else:
        return str(numero)

# %%
agrupado_concepto_frecuencia = (
    df.groupby(['CONCEPTO_TX'], as_index=False)
    .agg(
        frecuencia = ("CONCEPTO_TX",'count'),
        
        promedio_serie_pri=('MONTO_SERIE_PRI', lambda x: round(x.mean()) if not x.isna().all() else 0),
        maximo_serie_pri = ("MONTO_SERIE_PRI", 'max'),
        minimo_serie_pri = ("MONTO_SERIE_PRI", 'min'),
        
        
    )
    .sort_values('frecuencia', ascending=False)
)

# %%
agrupado_conceptos_frecuencia_x_año = (
    df.groupby(["AÑO_ENTRADA","CONCEPTO_TX"], as_index=False)
    .agg(
        frecuencia = ("CONCEPTO_TX",'count'),
        
        promedio_serie_pri=('MONTO_SERIE_PRI', lambda x: round(x.mean()) if not x.isna().all() else 0),
        maximo_serie_pri = ("MONTO_SERIE_PRI", 'max'),
        minimo_serie_pri = ("MONTO_SERIE_PRI", 'min'),
        
    )
    .sort_values('AÑO_ENTRADA', ascending=False)
)

# %%
agrupado_concepto_frecuencia.to_csv(os.path.join(ruta_salida,"agrupado_concepto_frecuencia.csv"), index=False)
agrupado_conceptos_frecuencia_x_año.to_csv(os.path.join(ruta_salida,"agrupado_conceptos_frecuencia_x_año.csv"), index=False)

# %%
agrupado_concepto_frecuencia.nlargest(1, "frecuencia")["CONCEPTO_TX"].iloc[0]
# Out:
# 'ENTREGA PATRIMONIAL'

# %%
agrupado_concepto_frecuencia.nsmallest(1, "promedio_serie_pri")["CONCEPTO_TX"].iloc[0]
# Out:
# 'ENTERO DE IVA'

# %%
agrupado_concepto_frecuencia.nlargest(1, "promedio_serie_pri")["CONCEPTO_TX"].iloc[0]
# Out:
# 'RETIRO DE RECURSOS PARA INVERSION EN OTROS INTERMEDIARIOS'

# %%
agrupado_concepto_frecuencia.nlargest(1, "frecuencia")["CONCEPTO_TX"].iloc[0]
agrupado_conceptos_frecuencia_x_año.loc[agrupado_conceptos_frecuencia_x_año["AÑO_ENTRADA"] == año].nsmallest(1, "frecuencia")["CONCEPTO_TX"].iloc[0], 
agrupado_conceptos_frecuencia_x_año.loc[agrupado_conceptos_frecuencia_x_año["AÑO_ENTRADA"] == año].nlargest(1, "promedio_serie_pri")["CONCEPTO_TX"].iloc[0]

# %%
agrupado_conceptos_frecuencia_x_año.loc[agrupado_conceptos_frecuencia_x_año["AÑO_ENTRADA"] == 2015, ["CONCEPTO_TX", "frecuencia"]].values.tolist()

# %%
agrupado_conceptos_frecuencia_x_año.loc[agrupado_conceptos_frecuencia_x_año["AÑO_ENTRADA"] == 2015].nsmallest(1, "frecuencia")["CONCEPTO_TX"].iloc[0]
# Out:
# 'PAGO DE ISR RETENIDO'

# %%
agrupado_conceptos_frecuencia_x_año
# Out:
#      AÑO_ENTRADA                                        CONCEPTO_TX  \
# 819         2025                           TRASPASO ENTRE CONTRATOS
# 798         2025      HONORARIOS POR SERVICIOS PROFESIONALES RET 6%
# 796         2025       HONORARIOS POR SERV. PROFESIONALES C/FACTURA
# 795         2025  HONORARIOS DE PUBLICACIONES OBLIGATORIAS C/FAC...
# 794         2025                         FONDEO PARA PAGO IVA E ISR
# ..           ...                                                ...
# 33          2012              PAGO CUOTAS BOLSA MEXICANA DE VALORES
# 32          2012                   PAGO ARRENDAMIENTO SIN RETENCION
# 31          2012                                   OTROS GASTOS N/C
# 30          2012                                       OBRA PUBLICA
# 0           2012                                             235106
#
#      frecuencia  promedio_serie_pri  maximo_serie_pri  minimo_serie_pri
# 819         101           204694013      2.632452e+09              0.06
# ...

# %%
[
    {
    'OPERACION': fil[1], 
    'PROMEDIO_MONTO_OPERACION': "{:,.0f} ".format(fil[3]),
    'MAX_MONTO': "{:,.0f} mx".format(fil[4]), 
    'MIN_MONTO': "{:,.0f} mx".format(fil[5])
    }
    for fil in agrupado_concepto_frecuencia.itertuples()
]

# %%
agrupado_conceptos_frecuencia_x_año
# Out:
#      AÑO_ENTRADA                                        CONCEPTO_TX  \
# 819         2025                           TRASPASO ENTRE CONTRATOS
# 798         2025      HONORARIOS POR SERVICIOS PROFESIONALES RET 6%
# 796         2025       HONORARIOS POR SERV. PROFESIONALES C/FACTURA
# 795         2025  HONORARIOS DE PUBLICACIONES OBLIGATORIAS C/FAC...
# 794         2025                         FONDEO PARA PAGO IVA E ISR
# ..           ...                                                ...
# 33          2012              PAGO CUOTAS BOLSA MEXICANA DE VALORES
# 32          2012                   PAGO ARRENDAMIENTO SIN RETENCION
# 31          2012                                   OTROS GASTOS N/C
# 30          2012                                       OBRA PUBLICA
# 0           2012                                             235106
#
#      frecuencia  promedio_serie_pri  maximo_serie_pri  minimo_serie_pri
# 819         101           204694013      2.632452e+09              0.06
# ...

# %%
{
    str(año): [
        {   
            'AÑO': str(año),
            'OPERACION': fil[1], 
            'PROMEDIO_MONTO_OPERACION': "{:,.0f} ".format(fil[3]),
            'MAX_MONTO': "{:,.0f} mx".format(fil[4]), 
            'MIN_MONTO': "{:,.0f} mx".format(fil[5])
        }
        for _, fil in agrupado_conceptos_frecuencia_x_año.loc[agrupado_conceptos_frecuencia_x_año["AÑO_ENTRADA"] == año].iterrows()
    ]
    for año in agrupado_conceptos_frecuencia_x_año["AÑO_ENTRADA"].unique()
}

# %%
agrupado_conceptos_frecuencia_x_año
# Out:
#      AÑO_ENTRADA                                        CONCEPTO_TX  \
# 819         2025                           TRASPASO ENTRE CONTRATOS
# 798         2025      HONORARIOS POR SERVICIOS PROFESIONALES RET 6%
# 796         2025       HONORARIOS POR SERV. PROFESIONALES C/FACTURA
# 795         2025  HONORARIOS DE PUBLICACIONES OBLIGATORIAS C/FAC...
# 794         2025                         FONDEO PARA PAGO IVA E ISR
# ..           ...                                                ...
# 33          2012              PAGO CUOTAS BOLSA MEXICANA DE VALORES
# 32          2012                   PAGO ARRENDAMIENTO SIN RETENCION
# 31          2012                                   OTROS GASTOS N/C
# 30          2012                                       OBRA PUBLICA
# 0           2012                                             235106
#
#      frecuencia  promedio_serie_pri  maximo_serie_pri  minimo_serie_pri
# 819         101           204694013      2.632452e+09              0.06
# ...

# %%
agrupado_fideicomiso = (
    df.groupby(["AÑO_ENTRADA", "CUSTOMER_ID", "LEGAL_NAME"], as_index=False)
    .agg(
        operacion_x_año=("ID_TRANSACTION", 'count'),
        promedio_serie_pri=('MONTO_SERIE_PRI', lambda x: round(x.median()) if not x.isna().all() else 0),
        maximo_serie_pri=("MONTO_SERIE_PRI", 'max'),
        minimo_serie_pri=("MONTO_SERIE_PRI", lambda x: round(x.min(), 2))  # Aquí corregí el uso de `min()`
    )
    .sort_values(['AÑO_ENTRADA', "CUSTOMER_ID"], ascending=False)
)

# %%
agrupado_fideicomiso
# Out:
#       AÑO_ENTRADA  CUSTOMER_ID  \
# 2895         2025      8022274
# 2894         2025      8022273
# 2893         2025      8022271
# 2892         2025      8022260
# 2891         2025      8022238
# ...           ...          ...
# 4            2012         2935
# 3            2012         2726
# 2            2012         2415
# 1            2012         1592
# 0            2012          567
#
#                                            LEGAL_NAME  operacion_x_año  \
# 2895                                  VOLKSWAGEN BANK                1
# 2894                     CONSUBANCO ANTES BANCO FACIL                1
# 2893        BANCO ACTIVER, SA (ANTES PRUDENTIAL BANK)                1
# 2892                   UBS CASA DE BOLSA S.A. DE C.V.                1
# 2891             Banco Santander (antes Banco Serfin)                1
# ...                                               ...              ...
# 4               Fonatur - Reserva P/Pens. al Personal               77
# ...

# %%
agrupado_fideicomiso.to_csv(os.path.join(ruta_salida,"agrupado_fideicomiso.csv"), index=False)

# %%
data_treemap_año_ope= {}; data_treemap_año_monto = {}
for año in agrupado_fideicomiso["AÑO_ENTRADA"].unique():
    filtrer_df = agrupado_fideicomiso[agrupado_fideicomiso["AÑO_ENTRADA"]==año]
    
    filtrer_df_prod = filtrer_df.nlargest(10, "operacion_x_año")
    filtrer_df_monto = filtrer_df.nlargest(10, "maximo_serie_pri")
    
    data_treemap_año_ope[str(año)] = [
        {"name":clt, "value": int(producto)}
        for clt, producto in zip(filtrer_df_prod["LEGAL_NAME"],filtrer_df_prod["operacion_x_año"])
    ] 
    data_treemap_año_monto[str(año)] = [
        {"name":clt, "value": round(monto,2)}
        for clt, monto in zip(filtrer_df_monto["LEGAL_NAME"],filtrer_df_monto["promedio_serie_pri"])
    ]

# %%
data_treemap_año_ope = {}
data_treemap_año_monto = {}

for año, filtrer_df in agrupado_fideicomiso.groupby("AÑO_ENTRADA"):
    print(filtrer_df.to_string(max_cols=None))
    data_treemap_año_ope[str(año)] = [
        {"name": clt, "value": int(ope)}
        for clt, ope in filtrer_df.nlargest(10, "operacion_x_año")[["LEGAL_NAME", "operacion_x_año"]].values
    ]
    
    data_treemap_año_monto[str(año)] = [
        {"name": clt, "value": round(monto, 2)}
        for clt, monto in filtrer_df.nlargest(10, "maximo_serie_pri")[["LEGAL_NAME", "promedio_serie_pri"]].values
    ]

# %%
df.columns
# Out:
# Index(['OID_CUSTOMERS', 'CUSTOMER_ID', 'LEGAL_NAME', 'DESCRIPTION', 'RFC',
#        'ADDRESS_DUMP', 'OID_ACCOUNTS', 'RFC2', 'ID_TRANSACTION',
#        'FECHA_DE_ENTRADA', 'FECHA_DE_ACUERDO', 'FECHA_DE_LIQUIDACION',
#        'FECHA_DE_ACUERDO_SERIE_PRI', 'FECHA_DE_ACUERDO_SERIE_SEC',
#        'FECHA_DE_FIN_DE_TRANSACCION', 'TASA_DE_TRANSACCION', 'COMENTARIOS_TX',
#        'CONCEPTO_TX', 'OBJETIVO_DEL_FIDEICOMISO', 'SUBTIPO_TX',
#        'MONTO_DE_COMISIONES', 'INTERES_LIMPIO_FUTURO', 'EXCEDENTE_UTILIZADO',
#        'MONTO_EN_DOLARES', 'TASA_DE_CAMBIO_DOLARES', 'MONTO_SERIE_PRI',
#        'MONTO_BRUTO', 'MONTO_ORDENADO', 'ID_DISPERSION', 'MONTO_DISPERSION',
#        'NOMBRE_DE_BENEFICIARIO', 'RFC_BENEFICIARIO', 'AÑO_ENTRADA',
#        'MES_ENTRADA', 'AÑO_ACUERDO', 'MES_ACUERDO', 'AÑO_LIQUIDACIÓN',
#        'MES_LIQUIDACIÓN'],
#       dtype='object')

# %%
df["SUBTIPO_TX"].value_counts()
# Out:
# SUBTIPO_TX
# CORTO PLAZO                                    803541
# Conciliación SIFC - TAS                        162199
# Pago de honorarios con cargo al patrimonio       8051
# Pago de honorarios con depósito del cliente      4819
# LARGO PLAZO                                      2172
# Inicialización de Acuerdos                         17
# Name: count, dtype: int64

# %%
df_plazo = df[["FECHA_DE_ENTRADA","FECHA_DE_LIQUIDACION"]].copy()

# %%
df_plazo["Plazo1"] = df_plazo.apply(lambda row: (row["FECHA_DE_LIQUIDACION"] - row["FECHA_DE_ENTRADA"]).days if (row["FECHA_DE_LIQUIDACION"] - row["FECHA_DE_ENTRADA"]).days > 0 else 0, axis=1)

# %%
df_plazo["AÑO_ENTRADA"] = df_plazo["FECHA_DE_ENTRADA"].apply(lambda x: x.year) 
df_plazo["MES_ENTRADA"] = df_plazo["FECHA_DE_ENTRADA"].apply(lambda x: x.month)

# %%
df_plazo["Plazo1"].mean()
# Out:
# 0.6943991007825288

# %%
agrupado_plazo = (
    df_plazo.groupby(["AÑO_ENTRADA"], as_index=False)
    .agg(
        plazo_medio = ("Plazo1",'mean'),
        max_plazo = ("Plazo1",'max'),
        min_plazo = ("Plazo1",'min')
    ).sort_values(['AÑO_ENTRADA'], ascending=False)
)

# %%
agrupado_plazo.to_csv(os.path.join(ruta_salida,"agrupado_plazo.csv"), index=False)

# %%
agrupado_plazo
# Out:
#     AÑO_ENTRADA  plazo  max_plazo  min_plazo
# 13         2025    0.0         47          0
# 12         2024    0.0        140          0
# 11         2023    0.0        302          0
# 10         2022    0.0        528          0
# 9          2021    0.0        981          0
# 8          2020    0.0        274          0
# 7          2019    0.0        400          0
# 6          2018    0.0        504          0
# 5          2017    0.0        731          0
# 4          2016    0.0       2932          0
# 3          2015    0.0       1137          0
# 2          2014    0.0       1144          0
# 1          2013    0.0       1832          0
# 0          2012    0.0         63          0

# %%
df_plazo
# Out:
#            FECHA_DE_ENTRADA FECHA_DE_ACUERDO            Plazo1
# 0       2012-02-01 11:31:17       2012-02-01 -1 days +12:28:43
# 1       2012-02-01 14:59:26       2012-02-01 -1 days +09:00:34
# 2       2012-02-01 15:01:11       2012-02-01 -1 days +08:58:49
# 3       2012-02-01 15:12:31       2012-02-01 -1 days +08:47:29
# 4       2012-02-01 14:03:37       2012-02-08   6 days 09:56:23
# ...                     ...              ...               ...
# 3149400 2025-02-19 18:09:28       2025-02-20   0 days 05:50:32
# 3149401 2025-02-19 18:11:40       2025-02-20   0 days 05:48:20
# 3149402 2025-02-19 18:15:55       2025-02-20   0 days 05:44:05
# 3149403 2025-02-19 17:29:55       2025-02-20   0 days 06:30:05
# 3149404 2025-02-19 17:55:44       2025-02-20   0 days 06:04:16
#
# [3149405 rows x 3 columns]

# %%
df["FECHA_DE_ENTRADA"] - DF[]

# %%
df["SUBTIPO_TX"].value_counts()
# Out:
# SUBTIPO_TX
# CORTO PLAZO                                    803541
# Conciliación SIFC - TAS                        162199
# Pago de honorarios con cargo al patrimonio       8051
# Pago de honorarios con depósito del cliente      4819
# LARGO PLAZO                                      2172
# Inicialización de Acuerdos                         17
# Name: count, dtype: int64

# %%
data_treemap_año_monto["2025"]
# Out:
# [{'name': 'FIDEICOMISO PRIVADO IRREVOCABLE DE ADMINISTRACIÓN Y FUENTE DE PAGO 80782',
#   'value': 3466510482.11},
#  {'name': 'Fideicomiso Promovido CFE TransCo', 'value': 2632452113.2},
#  {'name': 'CHIHUAHUA CEBURES 2013', 'value': 2188844849.43},
#  {'name': 'FIDEICOMISO DE ADMINISTRACIÓN Y PAGO SEDENA',
#   'value': 510363264.96},
#  {'name': 'FONDO DE PROTECCIÓN DE PAGOS', 'value': 362013773.53},
#  {'name': 'Pensiones Complementarias de Magistrados y Jueces Jubilados',
#   'value': 333547507.0},
#  {'name': 'Fideicomiso Privado de Financiamiento del NAICM',
#   'value': 300000000.0},
#  {'name': 'IPAB-BANPAIS', 'value': 227606001.0},
#  {'name': 'PERIFERICO DE MONTERREY CREDITO', 'value': 207657152.0},
#  {'name': 'Fideicomiso para el Desarrollo de Infraestructura que Implementa las Reformas Co',
#   'value': 204452140.0}]
